# %% [markdown]
# ##**Saatvik Sumanta Assignment-1**

# %% [markdown]
# ##**Pandas Data Frame with 10 observation and 5 Features**

# %%
import pandas as pd

# %%
d = {'Name':['A','B','C','D','E','F','G','H','I','J'],'Age':[22,21,23,21,24,25,23,26,25,27],'Height(in Cm)':[167,169,170,172,173,176,169,164,182,188],
     'Weight(in kg)':[65,75,72,66,69,72,78,60,65,70],'BMI':[23.3,26.3,24.9,22.3,23.1,23.2,27.3,22.3,19.6,19.8]}

# %%
df = pd.DataFrame(d)
df
# Out:
#   Name  Age  Height(in Cm)  Weight(in kg)   BMI
# 0    A   22            167             65  23.3
# 1    B   21            169             75  26.3
# 2    C   23            170             72  24.9
# 3    D   21            172             66  22.3
# 4    E   24            173             69  23.1
# 5    F   25            176             72  23.2
# 6    G   23            169             78  27.3
# 7    H   26            164             60  22.3
# 8    I   25            182             65  19.6
# 9    J   27            188             70  19.8

# %% [markdown]
# ##**Information on DataFrame Generated**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           10 non-null     object
#  1   Age            10 non-null     int64
#  2   Height(in Cm)  10 non-null     int64
#  3   Weight(in kg)  10 non-null     int64
#  4   BMI            10 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 528.0+ bytes

# %% [markdown]
# ##**Descriptive Statistics**

# %%
df.describe()
# Out:
#              Age  Height(in Cm)  Weight(in kg)        BMI
# count  10.000000       10.00000      10.000000  10.000000
# mean   23.700000      173.00000      69.200000  23.210000
# std     2.057507        7.25718       5.349974   2.482584
# min    21.000000      164.00000      60.000000  19.600000
# 25%    22.250000      169.00000      65.250000  22.300000
# 50%    23.500000      171.00000      69.500000  23.150000
# 75%    25.000000      175.25000      72.000000  24.500000
# max    27.000000      188.00000      78.000000  27.300000

# %% [markdown]
# ##**4th index observation usin loc**

# %%
df.loc[3]
# Out:
# Name                D
# Age                21
# Height(in Cm)     172
# Weight(in kg)      66
# BMI              22.3
# Name: 3, dtype: object
